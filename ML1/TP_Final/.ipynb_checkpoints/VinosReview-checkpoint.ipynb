# %% [markdown]
# # TP Final: Aprendizaje de Máquina I
#
# Para este TP obtuve el set de datos disponible en Kaggle (https://www.kaggle.com/zynicide/wine-reviews) relativo a una base de datos sobre opiniones realizadas por diversos sommeliers acerca de distintos vinos producidos alrededor del mundo. La idea es trabajar sobre el mismo aplicando los conceptos aprendidos en la materia.

# %% [markdown]
# ## Limpieza de datos
# Como primer medida debemos visualizar y limpiar los datos si fuese necesario. Lo primero a analizar es esas entradas que tengan valores vacíos en alguno de sus campos. Además deberemos analizar si hay campos completos de los que se pueda prescindir (ya sea porque les faltan demasiados valores o porque no presentan información relevante)

# %%
# Cargamos módulos necesarios
#============================
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns
sns.set_style("whitegrid", {'axes.grid' : False})
from sklearn.neighbors import KNeighborsRegressor

# %%
# Una vista de lo que contiene la tabla de datos
#===============================================
ds = pd.read_csv('winemag-data-130k-v2.csv')
ds.head(3)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
#
#     designation  points  price           province           region_1  \
# 0  Vulkà Bianco      87    NaN  Sicily & Sardinia               Etna
# 1      Avidagos      87   15.0              Douro                NaN
# 2           NaN      87   14.0             Oregon  Willamette Valley
#
#             region_2    taster_name taster_twitter_handle  \
# 0                NaN  Kerin O’Keefe          @kerinokeefe
# 1                NaN     Roger Voss            @vossroger
# 2  Willamette Valley   Paul Gregutt           @paulgwine
#
#                                            title         variety  \
# 0              Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1  Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# 2  Rainstorm 2013 Pinot Gris (Willamette Valley)      Pinot Gris
#
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm

# %%
ds.describe()
# De dónde sale el Unnamed:0 ???
# Out:
#           Unnamed: 0         points          price
# count  129971.000000  129971.000000  120975.000000
# mean    64985.000000      88.447138      35.363389
# std     37519.540256       3.039730      41.022218
# min         0.000000      80.000000       4.000000
# 25%     32492.500000      86.000000      17.000000
# 50%     64985.000000      88.000000      25.000000
# 75%     97477.500000      91.000000      42.000000
# max    129970.000000     100.000000    3300.000000

# %%
# La siguiente limpieza de datos está basada en el siguiente código: https://www.kaggle.com/milankalkenings/wine-reviews-data-cleaning
#------------------------------------------------------------------------------------------------------
def nullscan(ds_check, dcb):
    '''
    ds_check: el dataset que queremos verificar
    
    Grafica la proporción de valores null por columna en el DS usando el mapa caliente de seaborn y barplot
    '''    
    # Verificamos los nans
    ds_nulls = ds_check.isnull()
    # Cantidad de nulls por columna
    nulls_per_col = ds_nulls.sum(axis=0)
    print("Valores 'Null' por columna: \n \n", nulls_per_col)
    # the rate makes it way more interpretable:
    nulls_per_col /= len(ds_check.index)

    with plt.style.context('dark_background'):
        
        # Armamos la figura
        #------------------
        fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(8, 10))
    
        # colormap customizado
        vir = matplotlib.cm.get_cmap('viridis')
        colormap = matplotlib.colors.ListedColormap([vir(0), 'orange'])
        
        # Acá armamos el mapa de seaborn
        #-------------------------------
        sns.heatmap(ds_check.isnull(), cmap=colormap, cbar=dcb, yticklabels=False, ax=ax1)
        
        # Acá armamos el plot de barras
        #------------------------------
        nulls_per_col.plot(kind='bar', color='orange', x=nulls_per_col.values, y=nulls_per_col.index, ax=ax2, 
                       width=1, linewidth=1, edgecolor='black', align='edge', label='Proporción de valores Null')
        
        ax2.set_ylim((0,1))
        
        # centered labels
        labels=ds_check.columns
        ticks = np.arange(0.5, len(labels))
        ax2.xaxis.set(ticks=ticks, ticklabels=labels)
    
        # Ocultar "spines".
        ax2.spines['top'].set_color('black')
        ax2.spines['right'].set_color('black')
        
        # Viendo cómo visualizar muy poca cantidad de nulls por columna
        na_ticks = ticks[(nulls_per_col > 0) & (nulls_per_col < 0.05)]
        if (len(na_ticks) > 0):
            ax2.plot(na_ticks, [0,]*len(na_ticks), 's', c='orange', markersize=10, 
                     label='Muy pocos valores faltantes')
    
        fig.suptitle('Proporción de valores Null por columna', fontsize=30, y=1.05)
        ax2.legend()
        fig.tight_layout() 
        plt.savefig('nullscan.png')
        plt.show()

# Verifico los null en el dataset
#================================
nullscan(ds,True)
# Out:
# Valores 'Null' por columna:
#
#  Unnamed: 0                   0
# country                     63
# description                  0
# designation              37465
# points                       0
# price                     8996
# province                    63
# region_1                 21247
# region_2                 79460
# taster_name              26244
# taster_twitter_handle    31213
# title                        0
# variety                      1
# winery                       0
# dtype: int64

# %% [markdown]
# ### Manejo de valores vacíos (null)
#
# Luego de eliminar las filas (entradas) y/o columnas de datos vacíos que se pudieran debemos ver qué hacemos con aquellas entradas que no se pudieron eliminar y que queremos preservar (y utilizar en el análisis) \n
#
# Formas habituales de manejar valores nulos:
#
# - Eliminar filas que contengan una cantidad específica de valores nulos. Utilizar este método únicamente si el número de valores perdidos dentro de la fila respectiva es muy alto y dichos valores son relevantes.
# - Eliminar las columnas que contengan una cantidad específica de valores nulos si la columna no es demasiado relevante y la cantidad de valores perdidos es muy grande.
# - Reemplazar los valores faltantes con el promedio de la columna. El valor más común de una característica categórica y la mediana o la media de una característica numérica se pueden interpretar como el promedio de la columna respectiva.
# - Reemplazar el valor faltante con un valor predicho. Se podría usar KNN y reemplazar el valor faltante con el valor más frecuente dentro de los vecinos más cercanos.
# - Reemplazar los valores faltantes con ceros o 'Desconocido' y tratarlos como cualquier otro valor si es posible
# - Además de estos métodos estándar, una mayor comprensión del conjunto de datos y su contexto puede revelar otros métodos adecuados.

# %%
# Dado que las columnas 'country', 'province' y 'variety' tienen pocos valores Null
# eliminamos directamente esas filas completas para todos los campos.
#--------------------------------------------------------------------
ds = ds.dropna(subset=['country', 'province', 'variety'])

# Dado que la columna 'region_2' contiene demasiados Null la eliminamos directamente. (Sabiendo también
# que no nos agrega mucho esa columna como información relevante).
#-----------------------------------------------------------------
ds = ds.drop('region_2', axis=1)

# En el caso de los tipos de vinos 'designation' o las regiones 'region_1' que contienen datos vacíos
# es lógico indicarles un valor desconocido 'unknown' ya que son ambas variables categóricas, que no
# se les puede asignar otra etiqueta presente en dichas columnas sin corromper los datos. Por otro
# lado no tiene sentido eliminar esas filas o columnas porque el resto de los datos a los que esas
# entradas pertenecen aportan información relevante.
#---------------------------------------------------
ds[['designation', 'region_1']] = ds[['designation', 'region_1']].fillna('Unknown')

# También tenemos datos vacíos en las columnas 'tester_name' y 'tester_twitter_handle'. En estos campos
# ambos valores identifican a un mismo 'tester' o sommelier, por eso podría ser prudente realizar una
# unión entre ambos campos dando prioridad al campo 'tester_name'. Pero también podría pasar que un
# mismo sommelier tenga varias cuentas de twitter a través de las que realiza sus reviews (ya sea porque
# utiliza más de una o porque cierra una y abre otra). Para salir de dudas de cuál es la situación en
# este data set corremos el siguiente código.
# -------------------------------------------
only_name = ds.loc[ds['taster_twitter_handle'].isnull() & ds['taster_name'].notna(), 
                   ['taster_name', 'taster_twitter_handle']]
num_only_name = len(only_name.index)

only_twitter = ds.loc[ds['taster_name'].isnull() & ds['taster_twitter_handle'].notna(), 
                      ['taster_name', 'taster_twitter_handle']]
num_only_twitter = len(only_twitter.index)

print(f'Filas que contienen nombre pero no cuenta de twitter: {num_only_name} \nFilas que contienen cuenta de twitter pero no nombre: {num_only_twitter}')

# Dado el resultado anterior verificamos cuáles son los sommeliers que contienen múltiples cuentas de twitter
#------------------------------------------------------------------------------------------------------------
twitter_per_name = ds.groupby('taster_name')['taster_twitter_handle'].nunique()
print('\nCuentas de Twitter por Sommelier:\n')
print(twitter_per_name)
print('\n')

# Como se ve del resultado anterior o bien los sommeliers usan una cuenta de twitter o ninguna, por lo
# que simplemente se puede desechar la columna 'twitter_handle' y además rellenar los 'tester_name'
# vacíos con 'unknown'
#---------------------------------------------------------------------------------------------------
ds = ds.drop('taster_twitter_handle', axis=1)
ds['taster_name'] = ds['taster_name'].fillna('Unknown')

# Finalmente la única columna que queda aún con valores vacíos es la de precio 'price'. Se podría
# reemplazar todos los valores vacíos por la media de la columna...pero esto daría lugar a valores
# algo imprecisos. En cambio también se podría predecir esos valores utilizando KNN. Seguirían siendo
# 'valores inventados' pero con un criterio mucho más robusto con menor error. Para hacerlo se utilizarán
# las características 'country' y 'points' para agrupar. Por otro lado ya que se predecirán valores
# numéricos se utilizará un modelo de regresión (KNeighboursRegressor) de sklearn
#--------------------------------------------------------------------------------

# Cambiamos 'country' y 'taster_name' a variables de indexado
ds_cleanup = ds.loc[:, ['price', 'points', 'country', 'taster_name']]
encoded = pd.get_dummies(ds_cleanup[['country', 'taster_name']], prefix=['country', 'taster_name'])
ds_cleanup = pd.concat([ds_cleanup.drop(['country', 'taster_name'], axis=1), encoded], axis=1)

# Training data
ds_cleanup_known = ds_cleanup.loc[ds_cleanup['price'].notnull(), :]
X_known = ds_cleanup_known.drop('price', axis=1)
y_known = ds_cleanup_known['price']

# Prediction data
ds_cleanup_unknown = ds_cleanup.loc[ds_cleanup['price'].isnull(), :]
X_unknown = ds_cleanup_unknown.drop('price', axis=1)

# Creamos el regresor
knn_cleanup = KNeighborsRegressor(n_neighbors=10)
knn_cleanup.fit(X=X_known, y=y_known)

# Predecimos los precios y concatenamos los datos
ds_known = ds.loc[ds['price'].notnull(),:]
ds_predicted = ds.loc[ds['price'].isnull(),:]

# Para evadir SettingWithCopyWarning
ds_predicted = ds_predicted.drop('price', axis=1)
ds_predicted['price'] = knn_cleanup.predict(X_unknown)
ds = pd.concat([ds_known, ds_predicted], axis=0, ignore_index=True)

# Barajamos el dataset en las filas
#ds = ds.sample(frac=1).reset_index(drop=True)

# Finalmente mostramos cómo quedo el data set en relación a los null
#-------------------------------------------------------------------
nullscan(ds,False)
# Out:
# Filas que contienen nombre pero no cuenta de twitter: 4969
# Filas que contienen cuenta de twitter pero no nombre: 0
#
# Cuentas de Twitter por Sommelier:
#
# taster_name
# Alexander Peartree    0
# Anna Lee C. Iijima    0
# Anne Krebiehl MW      1
# Carrie Dykes          0
# Christina Pickard     1
# Fiona Adams           1
# Jeff Jenssen          1
# Jim Gordon            1
# Joe Czerwinski        1
# Kerin O’Keefe         1
# Lauren Buzzeo         1
# Matt Kettmann         1
# Michael Schachner     1
# Mike DeSimone         1
# Paul Gregutt          1
# Roger Voss            1
# Sean P. Sullivan      1
# Susan Kostrzewa       1
# Virginie Boone        1
# Name: taster_twitter_handle, dtype: int64
#
#
# Valores 'Null' por columna:
#
#  Unnamed: 0     0
# country        0
# description    0
# designation    0
# points         0
# price          0
# province       0
# region_1       0
# taster_name    0
# title          0
# variety        0
# winery         0
# dtype: int64

# %%
# Ya que los limpiamos los salvamos a disco así no tenemos que volverlo a hacer!!
#================================================================================
ds.to_csv('clean_data.csv')

# %%
# --> POSIBLE PUNTO DE ARRANQUE

# Si arrancamos desde acá (y no desde antes de limpiar los datos) entonces levantamos el archivo
#-----------------------------------------------------------------------------------------------
ds = pd.read_csv('clean_data.csv')

# %% [markdown]
# ## (mini)-ingeniería de características
# Más allá de las características (columnas) propias del dataset es posible extraer algunas características extra a partir de las mismas. Por ejemplo en el campo 'title' se ve que figuran los años de cada vino, dato que sería muy bueno tenerlo aislado. Veamos cómo recuperarlo!.
# (basado en https://www.kaggle.com/bowtiewarcry/wine-reviews-feature-engineering)

# %%
# Recuperamos la información de año del campo título
#===================================================

# Importamos el módulo para manejo de expresiones regulares
import re

yearSearch = [] 
for value in ds['title']:
    regexresult = re.search(r'19\d{2}|20\d{2}', value)
    if regexresult:
        yearSearch.append(regexresult.group())
    else: yearSearch.append(None)

ds['year'] = yearSearch

#Tell me which ones don't have a year listed
print("Se extrajeron %d registros de año de los títulos de vinos y %d no indicaban año." %(len(ds[ds['year'].notna()]), len(ds[ds['year'].isna()].index)))

print(ds['year'].describe())
ds.head(3)
# Out:
# Se extrajeron 125283 registros de año de los títulos de vinos y 4624 no indicaban año.
# count     125283
# unique        61
# top         2013
# freq       15865
# Name: year, dtype: object
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  country  \
# 0           0             0          104808       US
# 1           1             1          111724  Morocco
# 2           2             2          125817       US
#
#                                          description  \
# 0  A distinctive wine. The first impression is of...
# 1  Aromas of peach, green apple and freesia yield...
# 2  Nowhere near as good as the 2008, with an over...
#
#                                          designation  points  price  \
# 0  Saralee's Vineyard The Angel's Share Marsanne-...      92   33.0
# 1                                          Médallion      88   18.0
# 2                                            Unknown      85   38.0
#
#      province              region_1    taster_name  \
# 0  California  Russian River Valley        Unknown
# 1      Zenata               Unknown  Mike DeSimone
# 2  California           Napa Valley        Unknown
#
#                                                title                  variety  \
# 0  Lionheart 2007 Saralee's Vineyard The Angel's ...  Rhône-style White Blend
# 1  Ouled Thaleb 2012 Médallion Sauvignon Blanc (Z...          Sauvignon Blanc
# 2                Four Cairn 2009 Syrah (Napa Valley)                    Syrah
#
#          winery  year
# 0     Lionheart  2007
# 1  Ouled Thaleb  2012
# 2    Four Cairn  2009

# %%
# Eliminamos las entradas de los vinos que no tengan fecha
#=========================================================

# Si hay entradas sin fecha las eliminamos
ds=ds.dropna(subset=['year'])
print('Eliminadas ' + str(ds.shape[0]-ds.shape[0]) + ' Filas con campo año vacío.' + "\n")

ds['year']=ds['year'].astype(int)

print(ds['year'].describe())
# Out:
# Eliminadas 0 Filas con campo año vacío.
#
# count    125283.000000
# mean       2010.669660
# std           3.797799
# min        1904.000000
# 25%        2009.000000
# 50%        2011.000000
# 75%        2013.000000
# max        2017.000000
# Name: year, dtype: float64

# %%
# Hacemos un gráfico de puntuación Vs. Año
#-----------------------------------------
import matplotlib.style as style

dsWineYear = ds.groupby(['year']).mean()
dsWineYear = pd.DataFrame(data=dsWineYear).reset_index(drop=False)

style.use("seaborn-white")
plt.figure(figsize=(14,10))
ax = sns.barplot(y=dsWineYear['points'], x=dsWineYear['year'])
plt.title("Puntos promedio Vs. Año", fontsize=14)
plt.xlabel("Año")
plt.ylabel("Puntos")
ax.set(
    xlim=(0, len(dsWineYear)), 
    ylim=(85, 100)
)
ax.set_xticklabels(
    ax.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='medium'
)

plt.show()

#=================================================================
# CONCLUSIÓN MIRANDO EL GRÁFICO: Vinos asentados puntúan más alto!
#  - Salvo 1978 y 1980 que no anduvieron bien...
#=================================================================

# %%
# No entiendo de dónde sale Unnamed: 0.1 (igual que no entendía el Unnamed:0 de antes)
ds.describe()
# Out:
#           Unnamed: 0   Unnamed: 0.1         points          price  \
# count  125283.000000  125283.000000  125283.000000  125283.000000
# mean    64981.481813   65023.907992      88.485652      35.922131
# std     37508.055722   37530.595342       3.040949      40.982752
# min         0.000000       0.000000      80.000000       4.000000
# 25%     32507.500000   32512.500000      86.000000      17.100000
# 50%     64974.000000   65049.000000      88.000000      26.000000
# 75%     97492.500000   97533.500000      91.000000      42.000000
# max    129906.000000  129970.000000     100.000000    3300.000000
#
#                 year
# count  125283.000000
# mean     2010.669660
# std         3.797799
# min      1904.000000
# 25%      2009.000000
# 50%      2011.000000
# 75%      2013.000000
# max      2017.000000

# %% [markdown]
# ## Exploración de datos
# Una vez hecha la limpieza de datos empecemos a desentrañar la información que tenemos en nuestro dataset para elegir la mejor manera de utilizarla

# %%
# Veamos primero qué campos hay y de qué tipo de datos
ds.dtypes
# Out:
# Unnamed: 0          int64
# Unnamed: 0.1        int64
# Unnamed: 0.1.1      int64
# country            object
# description        object
# designation        object
# points              int64
# price             float64
# province           object
# region_1           object
# taster_name        object
# title              object
# variety            object
# winery             object
# year                int32
# dtype: object

# %% [markdown]
# ### Datos numéricos
# Los datos numéricos son los más fáciles de entender. En principio con lo que contamos son la puntuación que le dió el enólogo en cuestión (points), el precio que tiene de mercado (price) y el año de cosecha (year) que fue el dato que agregamos obteniéndolo del título

# %% [markdown]
# ### Viendo qué contienen los otros campos
# Podemos echarle una mirada a los otros campos para ver qué es lo que tienen adentro y como para ir viendo si vamos a utilizar toda la información disponible o si hay información que termine complejizando, no agregando o siendo supérflua como para no considerarla

# %%
# Echemos una mirada a alguno de los datos categóricos (object)
ds["country"].value_counts()
# Out:
# US                        53585
# France                    20511
# Italy                     18544
# Spain                      6133
# Portugal                   5374
# Chile                      4444
# Argentina                  3755
# Austria                    3304
# Australia                  2260
# Germany                    2149
# New Zealand                1409
# South Africa               1386
# Israel                      504
# Greece                      445
# Canada                      256
# Hungary                     143
# Bulgaria                    141
# Romania                     120
# Uruguay                     108
# Turkey                       90
# Slovenia                     85
# Georgia                      83
# Croatia                      72
# Mexico                       70
# England                      59
# Moldova                      57
# Brazil                       41
# Lebanon                      35
# Morocco                      28
# Peru                         16
# Macedonia                    12
# Serbia                       12
# Czech Republic               11
# Cyprus                       10
# India                         9
# Switzerland                   7
# Ukraine                       5
# Luxembourg                    3
# Bosnia and Herzegovina        2
# Armenia                       2
# Egypt                         1
# Slovakia                      1
# China                         1
# Name: country, dtype: int64

# %% [markdown]
# ##### Mini-conclusión
# Como se puede ver la mayoría de los vinos calificados son de Estados Unidos, estando Argentina en el 6to lugar con menos del 10% de las calificaciones de US. Podríamos decir que los tres productores principales clasificados son Estados Unidos, Francia e Italia. Ya podemos ver que hay países de origen con sus vinos calificados que podríamos descartar para el análisis

# %%
#ds["variety"].value_counts()[:20]
ds["variety"].value_counts()
# Out:
# Pinot Noir                  13123
# Chardonnay                  11469
# Cabernet Sauvignon           9447
# Red Blend                    8710
# Bordeaux-style Red Blend     6901
#                             ...
# Orangetraube                    1
# Chardonnay-Riesling             1
# Irsai Oliver                    1
# Biancale                        1
# Petit Courbu                    1
# Name: variety, Length: 692, dtype: int64

# %% [markdown]
# ##### Mini-conclusión
# Hay demasiadas cepas, quizás debamos particionar el dataset en este aspecto

# %%
ds["taster_name"].value_counts()
# Out:
# Unknown               25159
# Roger Voss            23867
# Michael Schachner     14536
# Kerin O’Keefe         10450
# Virginie Boone         9432
# Paul Gregutt           9416
# Matt Kettmann          6298
# Joe Czerwinski         5051
# Sean P. Sullivan       4913
# Anna Lee C. Iijima     4336
# Jim Gordon             4017
# Anne Krebiehl MW       3462
# Lauren Buzzeo          1795
# Susan Kostrzewa        1042
# Mike DeSimone           500
# Jeff Jenssen            453
# Alexander Peartree      395
# Carrie Dykes            134
# Fiona Adams              22
# Christina Pickard         5
# Name: taster_name, dtype: int64

# %% [markdown]
# #### Mini-conclusión
# La cantidad de sommeliers es manejable. Aunque se nota que hay muchos vinos que tienen calificador desconocido. Si la idea es obtener algún resultado relacionado con el sommelier deberíamos quitar esas entradas del dataset.

# %%
ds["winery"].value_counts()
# Out:
# Wines & Winemakers           221
# Testarossa                   218
# DFJ Vinhos                   215
# Williams Selyem              211
# Louis Latour                 199
#                             ...
# Domaine de la Graveirette      1
# Gordonzello                    1
# Org de Rac                     1
# PV Vinhos                      1
# Escalera                       1
# Name: winery, Length: 16334, dtype: int64

# %% [markdown]
# #### Mini-conslusión
# La cantidad de bodegas es monstruosa. Habrá que ver también cómo utilizar este dato, más que nada pensando en la codificación de este dato categórico

# %%
ds["province"].value_counts()
# Out:
# California           35635
# Washington            8565
# Bordeaux              5937
# Tuscany               5894
# Oregon                5334
#                      ...
# Elazığ-Diyarbakir        1
# Vinho da Mesa            1
# Urla-Thrace              1
# Ceres Plateau            1
# Paardeberg               1
# Name: province, Length: 419, dtype: int64

# %% [markdown]
# #### Mini-conclusión
# También hay demasiadas provincias. Idem conclusión anterior.

# %% [markdown]
# #### Analicemos un poco qué pasa con los sommeliers
# La idea es evaluar puntualmente este campo y ver cómo se comportan los sommeliers

# %%
# Veamos cómo puntúan:
#---------------------
agg_op1 = ds.groupby('taster_name').agg({
    'points': 'mean',
    'price': 'mean',
    'variety': 'count'
})
agg_op1.columns = ['mean_points','mean_price','frequency']
agg_op1.sort_values(by='frequency', ascending=False)
# Out:
#                     mean_points  mean_price  frequency
# taster_name
# Unknown               87.875591   37.419937      25159
# Roger Voss            88.725227   39.671463      23867
# Michael Schachner     86.919441   25.357347      14536
# Kerin O’Keefe         88.904115   41.807617      10450
# Virginie Boone        89.224767   46.788953       9432
# Paul Gregutt          89.105140   33.749915       9416
# Matt Kettmann         90.014925   38.524547       6298
# Joe Czerwinski        88.555930   35.063710       5051
# Sean P. Sullivan      88.776308   34.237472       4913
# Anna Lee C. Iijima    88.452721   30.045480       4336
# Jim Gordon            88.671894   27.205726       4017
# Anne Krebiehl MW      90.637493   31.457915       3462
# Lauren Buzzeo         87.767131   25.702340       1795
# Susan Kostrzewa       86.650672   23.191363       1042
# Mike DeSimone         89.098000   28.128200        500
# Jeff Jenssen          88.415011   22.456954        453
# Alexander Peartree    85.918987   29.262025        395
# Carrie Dykes          86.455224   31.008209        134
# Fiona Adams           87.045455   34.000000         22
# Christina Pickard     87.600000   29.200000          5

# %% [markdown]
# #### Mini-conclusión
# Como se ve Roger Voss es el sommelier que más calificaciones hizo dando un promedio de 89 puntos sobre 100, sobre vinos que tienen un valor promedio de USD39. El sommelier que más puntaje dio a los vinos que evaluó es Anne Krebiehl dando un puntaje promedio de 90.64/100 en vinos de valor promedio USD31.45

# %%
# Veamos ahora 
agg_op2 = ds.groupby(['taster_name','variety']).agg({
    'points':'mean',
    'price':'mean'
})
agg_op2.columns = ['mean_points','mean_price']
idmaxmin = agg_op2.groupby("taster_name").agg({"mean_points": ['idxmax', 'idxmin']})

tastermaxmin = pd.DataFrame(columns=['taster_name'], data=idmaxmin.index.values)
tastermaxmin['most_rated'] = idmaxmin.iloc[:,0].apply(lambda x: x[1]).values
tastermaxmin['least_rated'] = idmaxmin.iloc[:,1].apply(lambda x: x[1]).values
tastermaxmin
# Out:
#            taster_name                         most_rated  \
# 0   Alexander Peartree                            Touriga
# 1   Anna Lee C. Iijima                Riesling-Chardonnay
# 2     Anne Krebiehl MW                    Gelber Traminer
# 3         Carrie Dykes                           Meritage
# 4    Christina Pickard                             Shiraz
# 5          Fiona Adams                     Cabernet Franc
# 6         Jeff Jenssen                             Tokaji
# 7           Jim Gordon                    Champagne Blend
# 8       Joe Czerwinski                    Cabernet-Shiraz
# 9        Kerin O’Keefe                           Roviello
# 10       Lauren Buzzeo                     Grenache Blanc
# 11       Matt Kettmann                     Grenache Blend
# 12   Michael Schachner                     Tinta del Pais
# 13       Mike DeSimone  Cabernet Sauvignon-Cabernet Franc
# 14        Paul Gregutt                               Port
# 15          Roger Voss                          Terrantez
# 16    Sean P. Sullivan                     Grenache-Syrah
# 17     Susan Kostrzewa                          Kotsifali
# 18             Unknown                            Nosiola
# 19      Virginie Boone                     Moscato Giallo
#
#                 least_rated
# 0                     G-S-M
# 1                    Mavrud
# 2        Cabernet Sauvignon
# 3                  Riesling
# 4           Sauvignon Blanc
# 5                 Red Blend
# 6                  Saperavi
# 7                Fumé Blanc
# 8            Cabernet Franc
# 9                  Asprinio
# 10                    Gamay
# 11                Alvarinho
# 12           Müller-Thurgau
# 13                  Chinuri
# 14           Cabernet Blend
# 15  Gewürztraminer-Riesling
# 16             Muscat Blanc
# 17                 Nebbiolo
# 18               Chancellor
# 19                 Abouriou

# %% [markdown]
# #### Mini-conclusión
# Basado en lo anterior podemos decir que a Roger Voss el vino que más le gusta es el Terrantez (ojo, este es un vino de Madeira, Portugal. No tiene nada que ver con el Torrontés Argentino) y el que menos le gusta es el Gewürztraminer-Riesling (coincido, gusto a nada). A su vez a Anne Krebiehl el que más le gusta es el Gelber Traminer y el que menos es el Cabernet Sauvignon (que amarga que sos Anne! =) )

# %% [markdown]
# ## Preparación de datos
#
# En base a la exploración de datos realizada podemos ver que tenemos muchísimos y diversos datos y por lo tanto varias manera de relacionarlos. Para este trabajo vamos a elegir un subset reducido que nos permita trabajar de manera más sencilla con los mismos. Elegiremos un único varietal (Cabernet Sauvignon) y solo algunos campos puntuales:
#
# - __Salida:__
#     - Puntaje (points): Hay que elegir una/s salida/s para el análisis. Por lógica esta podría ser tanto precio como puntos otorgados por el sommelier. Empezamos seleccionando puntos ya que en algún momento vamos a querer ver si hay una relación entre el puntaje que recibe un vino y su precio en góndola...o vinoteca.
# - __Entradas:__ Podríamos haber elegido otras o más variantes. Pero empezaremos por estas a ver qué relaciones encontramos.
#     - Precio (price)
#     - Sommelier (taster_name)
#     - País (country)
#     - Año (year)
# <br>
#
# A su vez, dentro de nuestro dataset tenemos tanto variables continuas como categóricas. Para poder tratarlas en una estructura de árbol debemos convertir esas variables categóricas de alguna manera en numéricas. Hay varias aproximaciones a resolver este problema (me ayudó mucho leer del siguiente enlace: https://pbpython.com/categorical-encoding.html). La primer prueba fue realizar un one-hot-encoding, pero el número de variables agregadar por cada característica se hacía inmanejable en relación a los recursos de memoria (y entendimiento). Una aproximación mucho mejor, inclusive desde la lógica de lo que estamos buscando resolver es utilizar es hacer un encoding por diccionario.

# %%
# Vayamos con las entradas
#-------------------------

# Recordemos que nos queremos quedar únicamente con la cepa Cabernet Sauvignon para hacer el análisis
# sobre la misma
cabernet_data = ds.query("variety == 'Cabernet Sauvignon'")[['points','price','taster_name','country','year']]

# Vemos cómo quedó...
cabernet_data.dtypes
# Out:
# points           int64
# price          float64
# taster_name     object
# country         object
# year             int32
# dtype: object

# %%
# Recordemos que muchos de las entradas tenían taster_name = 'unknown'. Como queremos hacer un análisis
# basado también en los sommeliers nos embarra un poco la cancha no saber quién es el que terminó dando
# el puntaje, por lo que mejor eliminamos esas entradas
#------------------------------------------------------
# Encuentro los índices
indexUnknown = cabernet_data[ cabernet_data['taster_name'] == 'Unknown' ].index
cabernet_data.drop(indexUnknown , inplace=True)

cabernet_data["taster_name"].value_counts()
# Out:
# Virginie Boone        1826
# Michael Schachner     1354
# Sean P. Sullivan       785
# Paul Gregutt           676
# Matt Kettmann          454
# Jim Gordon             394
# Joe Czerwinski         263
# Lauren Buzzeo          138
# Anna Lee C. Iijima      91
# Susan Kostrzewa         67
# Mike DeSimone           65
# Roger Voss              47
# Jeff Jenssen            35
# Kerin O’Keefe           32
# Alexander Peartree       8
# Carrie Dykes             7
# Fiona Adams              6
# Anne Krebiehl MW         2
# Name: taster_name, dtype: int64

# %%
cabernet_data["country"].value_counts()
# Out:
# US              4261
# Chile            749
# Argentina        540
# Australia        245
# South Africa     118
# Israel           104
# Spain             50
# France            47
# Italy             37
# Bulgaria          20
# Romania           16
# Portugal          16
# Moldova            8
# Mexico             7
# Canada             7
# Greece             6
# Austria            5
# Brazil             4
# Slovenia           3
# New Zealand        2
# Turkey             2
# Uruguay            2
# Ukraine            1
# Name: country, dtype: int64

# %%
# Tenemos estos dos campos que son categóricos. Tenemos que encontrar alguna manera de codificarlos
# pero también notamos que hay algunos países que tienen pocas entradas y algunos sommeliers que
# calificaron pocos vinos. Por lo tanto elegimos quedarnos con los doce primeros que tienen mayores
# entradas de cada característica.
#-----------------------------------------------------------------------
# Encuentro los índices
indexDrop1 = cabernet_data[ (cabernet_data['taster_name'] == 'Jeff Jenssen') |
                           (cabernet_data['taster_name'] == 'Kerin O’Keefe') |
                           (cabernet_data['taster_name'] == 'Alexander Peartree') |
                           (cabernet_data['taster_name'] == 'Carrie Dykes') |
                           (cabernet_data['taster_name'] == 'Fiona Adams') |
                           (cabernet_data['taster_name'] == 'Anne Krebiehl MW')].index

# Elimino
cabernet_data.drop(indexDrop1 , inplace=True)

# Encuentro los índices
indexDrop2 = cabernet_data[ (cabernet_data['country'] == 'Moldova') |
                          (cabernet_data['country'] == 'Mexico') |
                          (cabernet_data['country'] == 'Canada') |
                          (cabernet_data['country'] == 'Greece') |
                          (cabernet_data['country'] == 'Austria') |
                          (cabernet_data['country'] == 'Brazil') |
                          (cabernet_data['country'] == 'Slovenia') |
                          (cabernet_data['country'] == 'New Zealand') |
                          (cabernet_data['country'] == 'Turkey') |
                          (cabernet_data['country'] == 'Uruguay') |
                          (cabernet_data['country'] == 'Ukraine')].index

# Elimino
cabernet_data.drop(indexDrop2 , inplace=True)

print(cabernet_data["taster_name"].value_counts())
print('\n')
print(cabernet_data["country"].value_counts())
# Out:
# Virginie Boone        1826
# Michael Schachner     1341
# Sean P. Sullivan       784
# Paul Gregutt           672
# Matt Kettmann          454
# Jim Gordon             394
# Joe Czerwinski         261
# Lauren Buzzeo          138
# Anna Lee C. Iijima      88
# Mike DeSimone           64
# Susan Kostrzewa         60
# Roger Voss              44
# Name: taster_name, dtype: int64
#
#
# US              4240
# Chile            749
# Argentina        540
# Australia        245
# South Africa     118
# Israel           104
# Spain             50
# France            47
# Portugal          16
# Romania            8
# Italy              5
# Bulgaria           4
# Name: country, dtype: int64

# %%
# Ahora hacemos el encoding por el método de 
#--------------------------
cabernet_data["country"] = cabernet_data["country"].astype('category')
cabernet_data["country"] = cabernet_data["country"].cat.codes

cabernet_data["taster_name"] = cabernet_data["taster_name"].astype('category')
cabernet_data["taster_name"] = cabernet_data["taster_name"].cat.codes

cabernet_data.head(20)
# Out:
#      points  price  taster_name  country  year
# 8        90   25.0           11       11  2013
# 27       85   18.0            7       11  2010
# 58       88   25.0            9       11  2013
# 131      90   90.0           11       11  2012
# 170      89   50.0           11       11  2011
# 172      91   35.0            7       11  2009
# 182      92   45.0            2        1  2012
# 201      82   25.0           11       11  2013
# 209      86   14.0            5        0  2014
# 215      90   12.0            5        3  2001
# 226      87   12.0            5        3  2008
# 247      91   45.0            7       11  2010
# 274      88   28.0           11       11  2012
# 288      90   45.0            9       11  2013
# 293      86   20.0            4       11  2014
# 302      90   25.0            4       11  2014
# 309      89   15.0            5       10  2005
# 333      91   20.0            5        3  2012
# 345      89   20.0            1       11  2013
# 361      86   12.0            5        3  2010

# %%
# Armo los diccionarios
country_cat2id = {id:idx for id,idx in zip(vendor_id, vendor_idx)}

# %% [markdown]
# ## Visualización de la información en árboles

# %%
# Como dijimos la salida va a ser el puntaje
#-------------------------------------------
y = cabernet_data['points']

# %%
# Para los X solo tengo que descartar la salida
#----------------------------------------------
X = cabernet_data.drop('points', axis=1)

# %%
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
from dtreeviz.trees import dtreeviz # remember to load the package

# %%
y.shape
# Out:
# (6126,)

# %%
# Fit the classifier with default hyper-parameters
clf = DecisionTreeClassifier(random_state=1234)
model = clf.fit(X, y)

#Print Text Representation
#Exporting Decision Tree to the text representation can be useful when 
#working on applications whitout user interface or when we want to log information about the model into the text file.

text_representation = tree.export_text(clf)
print(text_representation)

with open("decision_tree.log", "w") as fout:
    fout.write(text_representation)

#Plot Tree with plot_tree

#The plot_tree method was added to sklearn in version 0.21. It requires matplotlib 
#to be installed. It allows us to easily produce figure of the tree (without intermediate exporting to graphviz)

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(clf,
                   feature_names = list(X.columns),
                   class_names = list(['points']),
                   filled=False)

fig.savefig("decision_tree.png")

#Visualize Decision Tree with graphviz
#Please make sure that you have graphviz installed (pip install graphviz). 
#To plot the tree first we need to export it to DOT format with export_graphviz method

#import graphviz
# DOT data
#dot_data = tree.export_graphviz(clf, out_file=None, 
#                                feature_names=iris.feature_names,  
#                                class_names=iris.target_names,
#                                filled=True)

# Draw graph
#graph = graphviz.Source(dot_data, format="png") 
#graph
#graph.render("decision_tree_graphivz")

#Plot Decision Tree with dtreeviz Package
#The dtreeviz package is available in github. It can be installed with pip install dtreeviz. 
#It requires graphviz to be installed (but you dont need to manually convert between DOT files and images)

#viz = dtreeviz(clf, X, y,
#                target_name="target",
#                feature_names=iris.feature_names,
#                class_names=list(iris.target_names))
#viz
# Out:
# |--- feature_0 <= 28.70
# |   |--- feature_0 <= 14.45
# |   |   |--- feature_0 <= 11.50
# |   |   |   |--- feature_0 <= 8.50
# |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |--- class: 87
# |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2014.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |--- feature_3 >  2012.00
# |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |--- feature_3 >  2014.00
# |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2000.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1999.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |--- feature_3 >  1999.50
# |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |--- feature_3 >  2000.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 6.50
# |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |--- feature_0 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 3.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |--- feature_1 >  3.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 6.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  6.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |--- feature_0 >  8.50
# |   |   |   |   |--- feature_2 <= 4.50
# |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |--- feature_1 <= 1.00
# |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |--- feature_1 >  1.00
# |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |--- feature_3 >  2012.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  4.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 80
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2000.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1999.50
# |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |--- feature_3 >  1999.50
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_3 >  2000.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2004.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2004.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2006.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2002.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2002.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2006.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2015.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2015.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2015.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2015.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |--- feature_2 >  4.50
# |   |   |   |   |   |--- feature_1 <= 8.50
# |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2007.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2007.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 10.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  10.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |--- feature_2 <= 8.00
# |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |--- feature_2 >  8.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |--- feature_1 >  8.50
# |   |   |   |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2011.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2011.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |   |   |   |--- feature_0 <= 10.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 10.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |--- feature_2 >  10.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_0 >  10.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2006.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2006.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |--- feature_0 >  11.50
# |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2006.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |--- feature_3 >  2006.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.75
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.75
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |--- feature_3 <= 2015.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 80
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.90
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |--- feature_3 >  2015.50
# |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2006.50
# |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |--- feature_3 >  2006.50
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |--- feature_3 <= 2004.50
# |   |   |   |   |   |--- feature_3 <= 1998.50
# |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |--- feature_3 >  1998.50
# |   |   |   |   |   |   |--- feature_3 <= 2002.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2001.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 13.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |--- feature_0 >  13.50
# |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |--- feature_3 >  2001.50
# |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |--- feature_3 >  2002.50
# |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |--- feature_3 >  2004.50
# |   |   |   |   |   |--- feature_0 <= 13.45
# |   |   |   |   |   |   |--- feature_1 <= 10.50
# |   |   |   |   |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2015.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2015.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |--- feature_2 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  7.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |--- feature_1 >  10.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 12.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 80
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  12.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |--- feature_0 >  13.45
# |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |--- feature_1 <= 6.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |--- feature_1 >  6.00
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2008.00
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_3 >  2008.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  9.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  8.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 3.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  3.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  7.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |--- feature_1 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 9.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2014.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  9.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |--- feature_0 >  14.45
# |   |   |--- feature_0 <= 19.05
# |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |--- feature_2 <= 10.50
# |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2004.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |   |--- feature_3 >  2004.50
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 5.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 4.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  4.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2006.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2006.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |--- feature_1 >  5.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2006.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2006.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2004.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  5.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |--- feature_3 >  2004.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |   |--- feature_2 <= 4.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |--- feature_2 >  4.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 16.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |--- feature_0 >  16.00
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |--- feature_2 >  10.50
# |   |   |   |   |   |--- feature_3 <= 2006.50
# |   |   |   |   |   |   |--- feature_3 <= 2001.00
# |   |   |   |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1997.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1997.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 1997.50
# |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |--- feature_3 >  1997.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 1998.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  1998.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_3 >  2001.00
# |   |   |   |   |   |   |   |--- feature_1 <= 8.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2004.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2004.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  16.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |--- feature_1 >  8.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 17.00
# |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |   |--- feature_0 >  17.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 84
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |--- feature_3 >  2006.50
# |   |   |   |   |   |   |--- feature_1 <= 8.00
# |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2007.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 17.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  17.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2007.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_1 >  8.00
# |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 18.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 10.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  10.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_0 >  18.50
# |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 15.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 10.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  10.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 82
# |   |   |   |   |   |   |   |   |--- feature_0 >  15.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 17.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  17.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 10.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  10.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |--- feature_0 <= 15.85
# |   |   |   |   |   |--- feature_1 <= 6.00
# |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |--- feature_1 <= 4.50
# |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 15.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  15.35
# |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |--- class: 83
# |   |   |   |   |   |   |   |--- feature_1 >  4.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- class: 81
# |   |   |   |   |   |   |   |   |--- feature_2 >  1.50
# |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2015.50
# |   |   |   |   |   |   |   |   |--- feature_2 <= 2.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 86
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 80
# |   |   |   |   |   |   |   |   |--- feature_2 >  2.00
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# ...
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  98.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 9.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  9.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_0 >  103.00
# |   |   |   |   |   |   |   |--- feature_0 <= 106.50
# |   |   |   |   |   |   |   |   |--- class: 87
# |   |   |   |   |   |   |   |--- feature_0 >  106.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 122.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 10.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 96
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 85
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  10.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2010.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_0 >  122.50
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2005.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2005.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |--- feature_1 <= 10.00
# |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 99.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 97.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  97.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |   |--- feature_0 >  99.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 112.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 89
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  112.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 130.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  130.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 99.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 97.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  97.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  99.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 103.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  103.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 97.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 94.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  94.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  97.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 99.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  99.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- feature_1 >  10.00
# |   |   |   |   |   |   |   |--- feature_0 <= 110.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 97.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  97.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 102.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  97.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  102.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 107.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  107.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |--- feature_0 >  110.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 132.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 116.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  116.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  132.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 135.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  135.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 127.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  122.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  127.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 132.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  132.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- feature_0 >  139.00
# |   |   |   |   |--- feature_3 <= 2013.50
# |   |   |   |   |   |--- feature_2 <= 7.00
# |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 157.50
# |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |   |--- feature_0 >  157.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 177.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 88
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  177.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 190.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  190.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 95
# |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 325.00
# |   |   |   |   |   |   |   |   |   |--- class: 91
# |   |   |   |   |   |   |   |   |--- feature_0 >  325.00
# |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |--- feature_2 >  7.00
# |   |   |   |   |   |   |--- feature_0 <= 247.50
# |   |   |   |   |   |   |   |--- feature_1 <= 2.50
# |   |   |   |   |   |   |   |   |--- class: 95
# |   |   |   |   |   |   |   |--- feature_1 >  2.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2008.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 174.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  174.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2006.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2006.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |   |--- feature_3 >  2008.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |--- feature_0 >  247.50
# |   |   |   |   |   |   |   |--- feature_3 <= 2012.50
# |   |   |   |   |   |   |   |   |--- feature_3 <= 2010.50
# |   |   |   |   |   |   |   |   |   |--- class: 95
# |   |   |   |   |   |   |   |   |--- feature_3 >  2010.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 295.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 257.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 98
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  257.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 98
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  295.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  2011.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 95
# |   |   |   |   |   |   |   |--- feature_3 >  2012.50
# |   |   |   |   |   |   |   |   |--- feature_0 <= 267.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 255.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  255.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 92
# |   |   |   |   |   |   |   |   |--- feature_0 >  267.50
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 412.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 96
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  412.50
# |   |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |--- feature_3 >  2013.50
# |   |   |   |   |   |--- feature_2 <= 6.00
# |   |   |   |   |   |   |--- class: 95
# |   |   |   |   |   |--- feature_2 >  6.00
# |   |   |   |   |   |   |--- feature_0 <= 205.00
# |   |   |   |   |   |   |   |--- feature_0 <= 185.00
# |   |   |   |   |   |   |   |   |--- feature_0 <= 145.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 10.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  10.00
# |   |   |   |   |   |   |   |   |   |   |--- class: 93
# |   |   |   |   |   |   |   |   |--- feature_0 >  145.00
# |   |   |   |   |   |   |   |   |   |--- feature_0 <= 170.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 160.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  160.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 95
# |   |   |   |   |   |   |   |   |   |--- feature_0 >  170.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 177.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  177.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |   |--- feature_0 >  185.00
# |   |   |   |   |   |   |   |   |--- class: 90
# |   |   |   |   |   |   |--- feature_0 >  205.00
# |   |   |   |   |   |   |   |--- feature_0 <= 217.50
# |   |   |   |   |   |   |   |   |--- class: 94
# |   |   |   |   |   |   |   |--- feature_0 >  217.50
# |   |   |   |   |   |   |   |   |--- class: 94
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-123-39b610d346e7> in <module>
#      22                    feature_names = list(X.columns),
#      23                    class_names = list(['points']),
# ---> 24                    filled=False)
#      25
#      26 fig.savefig("decision_tree.png")
#
# ~\Anaconda3\envs\AI\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\Anaconda3\envs\AI\lib\site-packages\sklearn\tree\_export.py in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rotate, rounded, precision, ax, fontsize)
#     191         proportion=proportion, rotate=rotate, rounded=rounded,
#     192         precision=precision, fontsize=fontsize)
# --> 193     return exporter.export(decision_tree, ax=ax)
#     194
#     195
#
# ~\Anaconda3\envs\AI\lib\site-packages\sklearn\tree\_export.py in export(self, decision_tree, ax)
#     583         ax.set_axis_off()
#     584         my_tree = self._make_tree(0, decision_tree.tree_,
# --> 585                                   decision_tree.criterion)
#     586         draw_tree = buchheim(my_tree)
#     587
#
# ~\Anaconda3\envs\AI\lib\site-packages\sklearn\tree\_export.py in _make_tree(self, node_id, et, criterion, depth)
#     563         # traverses _tree.Tree recursively, builds intermediate
#     564         # "_reingold_tilford.Tree" object
# --> 565         name = self.node_to_str(et, node_id, criterion=criterion)
#     566         if (et.children_left[node_id] != _tree.TREE_LEAF
#     567                 and (self.max_depth is None or depth <= self.max_depth)):
#
# ~\Anaconda3\envs\AI\lib\site-packages\sklearn\tree\_export.py in node_to_str(self, tree, node_id, criterion)
#     352                 node_string += 'class = '
#     353             if self.class_names is not True:
# --> 354                 class_name = self.class_names[np.argmax(value)]
#     355             else:
#     356                 class_name = "y%s%s%s" % (characters[1],
#
# IndexError: list index out of range
